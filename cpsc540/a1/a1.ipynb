# %%
using Pkg
Pkg.add("JLD")
Pkg.add("PyPlot")
Pkg.build("HDF5")
# Out:
#   Updating registry at `C:\Users\Kyle\.julia\registries\General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `C:\Users\Kyle\.julia\environments\v1.0\Project.toml`
#  [no changes]
#   Updating `C:\Users\Kyle\.julia\environments\v1.0\Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `C:\Users\Kyle\.julia\environments\v1.0\Project.toml`
#  [no changes]
#   Updating `C:\Users\Kyle\.julia\environments\v1.0\Manifest.toml`
#  [no changes]
#   Building LibCURL ─→ `C:\Users\Kyle\.julia\packages\LibCURL\OoXMv\deps\build.log`
#   Building WinRPM ──→ `C:\Users\Kyle\.julia\packages\WinRPM\Y9QdZ\deps\build.log`
#   Building Homebrew → `C:\Users\Kyle\.julia\packages\Homebrew\l8kUw\deps\build.log`
#   Building CMake ───→ `C:\Users\Kyle\.julia\packages\CMake\ZGawK\deps\build.log`
#   Building Blosc ───→ `C:\Users\Kyle\.julia\packages\Blosc\lzFr0\deps\build.log`
# ...

# %%
include("example_nonLinear.jl")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# TestError = 3393.87
# (-300, 400)
